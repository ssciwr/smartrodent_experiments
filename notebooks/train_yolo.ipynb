# %%
import ultralytics
import pandas as pd
import matplotlib.pyplot as plt
import torch
from smartrodent import YoloDetectorTrainer
import json

# %%
trainer = YoloDetectorTrainer.from_config(
    "/home/hmack/Development/rodent_experiments/configs/train_detector_config.json"
)

# %%
history = trainer.train()
