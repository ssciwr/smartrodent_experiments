# %%
import ultralytics
import pandas as pd
import matplotlib.pyplot as plt
import torch
from smartrodent import YoloDetectorTrainer
import json
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
trainer = YoloDetectorTrainer.from_config(
    "/home/hmack/projects/smartrodent_experiments/configs/train_detector_config.json"
)

# %%
trainer.model.ckpt["train_args"]

# %%
history = trainer.train()

# %%
trainer.model.export()
